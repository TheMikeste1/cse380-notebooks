# %% [markdown]
# <a href="https://colab.research.google.com/github/byui-cse/cse380-notebooks/blob/master/07_3_About_Deeper_Elementary_Number_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About Deeper Elementary Number Theory
# ## Class Directed Learning
# ### Due: Wednesday, 17 February 2021, 11:59 pm

# %% [markdown]
# ## Read and Ponder
# https://byui-cse.github.io/cse380-course/about-deeper-elementary-number-theory.pdf
#
# Put your answers in cells you will add below.
#
# Above and beyond behavior: Incorporate the material in the PDF into this notebook.

# %% [markdown]
# ## The Fundamental Theorem of Arithmetic
# Let $P =$ the set of prime numbers, $N =$ the set of natural (nonnegative) numbers, and $Z^+ =$ the set of positive integers. If $L^+(P, N)$ is the set of functions $f : P → N$ with the property that
#
# $$∃n ∈ N ∀p ∈ P [p ≥ n ⇒ f(p) = 0],$$
#
# then there exists a bijection $Z^+ → L^+(P, N)$ such that if $z → f$ then
#
# $$z = \prod_{p∈P} p^{f(p)} .$$

# %% [markdown]
# According to the Fundamental Theorem of Arithmetic, each positive integer $n$ can be expressed in the form
#
# $$n = 2^{e_2}3^{e_3}5^{e_5}7^{e_7}11^{e_{11}} \ldots =
# \prod_{p \;\textbf{prime}} p^{e_p},$$
#
# where the exponents $e_2, e_3, \ldots$ are uniquely determined nonnegative integers, and where all but a finite number of the exponents are zero.
# \
# \
# \
# — Donald Knuth, writing with **clarity** what the previous page is trying to say.

# %% [markdown]
# ## TODO Explore Fermat’s Little Theorem Further

# %% [markdown]
# ### Answer to Yesterday’s DPC

# %% [markdown]
# 0&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp; 1\
# 1&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; 1 1\
# **2**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 **2** 1\
# **3**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp; 1 **3 3** 1\
# 4&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 4 6 4 1\
# **5**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 **5 10 10 5** 1\
# 6&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; 1 6 15 20 15 6 1\
# **7**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp; 1 **7 21 35 35 21 7** 1\
# 8&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 8 28 56 70 56 28 8 1\
# 9&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 9 36 84 126 126 84 36 9 1\
# 10&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 10 45 120 210 252 210 120 45 10 1\
# **11**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 **11 55 165 330 462 462 330 165 55 11** 1\
# 12&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1 12 66 220 495 792 924 792 495 220 66 12 1\
# **13**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; 1 **13 78 286 715 1287 1716 1716 1287 715 286 78 13** 1\
# 14&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; 1 14 91 364 1001 2002 3003 3432 3003 2002 1001 364 91 14 1\
# 15&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; 1 15 105 455 1365 3003 5005 6435 6435 5005 3003 1365 455 105 15 1\
# 16&emsp;&emsp;&emsp;&emsp;&nbsp; 1 16 120 560 1820 4368 8008 11440 12870 11440 8008 4368 1820 560 120 16 1\
# **17**&emsp; 1 **17 136 680 2380 6188 12376 19448 24310 24310 19448 12376 6188 2380 680 136 17** 1

# %% [markdown]
# Step number 7 in the FLT proof by induction is the answer — only prime-numbered rows
# in Pascal’s triangle show the pattern. The step is correctly rendered as:
#
# > In terms of division by $N$, the $N \choose K$ terms can't matter, since, except for the first and last 1's in each row - $N \choose 0$ and $N \choose N$ - $N$ divides $N \choose K$ **when $N$ is prime**.

# %% [markdown]
# ### Explore Another Proof

# %% [markdown]
# Here is another proof of Fermat’s Little Theorem:
# 1. Suppose we have beads in $X$ different colors, and we wish to make bracelets using exactly $N$ beads.
# 2. First we put $N$ beads on a string.
# 3. Since each of the beads can be chosen in $X$ ways, by the product rule there are $X^N$ possible strings.
# 4. For each of the $X$ colors, there is one string entirely of that color, which we throw away, leaving $X^N − X$ strings.
# 5. We join the two ends of each of these remaining strings to form bracelets.
# 6. We observe that if two strings differ only by a cyclic permutation of the beads, the resulting bracelets will be indistinguishable.
# 7. There are $N$ cyclic permutations of the $N$ beads on a string.
# 8. Therefore the number of distinguishable bracelets is $(X^N − X)/N$.
# 9. Therefore $(X^N − X)/N$ must be an integer.
# 10. Therefore $X^N − X$ is divisible by $N$.
# 11. Q.E.D.
#
# The hypothesis ($N$ is prime) is implicitly used in one step of this proof. In other words, if “Blah” is what the step says, to be complete it should say “Blah, since $N$ is prime.” Which step is it?
#
# Find an explanation of this proof online in written or video form.

# %% [markdown]
# ## TODO Explore Primes and Probability Further

# %% [markdown]
# You have already seen one connection between **coprimality** and probability in the determination that the probability that two randomly chosen positive integers are coprime being the reciprocal $(6/π^2)$ of the sum of the reciprocals of the squares of the positive integers $(π^2/6)$.
#
# There are other connections between primality and probability!
#
# A **probabilistic algorithm** is an algorithm that might give the incorrect answer, but only with small probability. For example, there are good probabilistic algorithms that test whether or not a natural number is prime. Many of these are based on a **deterministic** test using **Fermat’s little theorem**, which, going back to the first statement of it, says that if $N$ is prime, then $N$ divides $X^N - X$. Which implies that if $N$ doesn’t divide $X^N - X$ for some $X$, then $N$ **can’t** be prime.
#
# Unfortunately, this test doesn’t always work, because pseudoprimes fool it.
#
# In the book is a brief mention of the **Prime Number Theorem**. This theorem states that the number of primes not exceeding (less than or equal to) the number $n$ is approximately equal to $n / \log n$. Can you use this theorem to estimate the probability that a randomly chosen $k$-digit number is prime?

# %% [markdown]
# # Reponse

# %% [markdown]
# ##Explore Another Proof:
#
# Step 7 implicitly uses the hypothesis $N$ is prime. This is because the cycles of composite values of $N$ will contain subcycles of the prime factors of $N$, resulting in a different number of groups.\
# [Video proof](https://www.khanacademy.org/computing/computer-science/cryptography/random-algorithms-probability/v/fermat-s-little-theorem-visualization)

# %% [markdown]
# ## Explore Primes and Probability Further

# %% [markdown]
# The maximum $n$ with $k$ digits is $10^k - 1$. Therefore, the number of primes up to max($n$) is $\frac{10^k - 1}{\log{(10^k - 1)}}$.
#
# However, we need to remove those numbers which do not have $k$ digits. This can be accomplished with $\frac{10^k - 1}{\log{(10^k - 1)}} - \frac{10^{k - 1} - 1}{\log{(10^{k - 1} - 1)}}$. This gives us the approximation for the total number of primes with $k$ digits.
#
# Finally, we need to count how many total $n$'s are within range:
#
# $$10^k - 1 - (10^{k - 1} - 1) = 10^k - 10^{k - 1}$$

# %%
k = 4

# %%
10 ** k - 10 ** (k - 1)
# Out:
# 9000

# %%
len(range(10 ** (k - 1) - 1, 10 ** k - 1))  # Proof by listing all the numbers
# Out:
# 9000

# %% [markdown]
# Finally, to get the probability of choosing a prime, we divide the estimated number of primes by the total numbers:
#
# $$\frac{\frac{10^k - 1}{\log{(10^k - 1)}} - \frac{10^{k - 1} - 1}{\log{(10^{k - 1} - 1)}}}{10^k - 10^{k - 1}} =
# \frac{10^k - 1}{(10^k - 10^{k - 1})\log{(10^k - 1)}} - \frac{10^{k - 1} - 1}{(10^k - 10^{k - 1})\log{(10^{k - 1} - 1)}}
# $$

# %%
from decimal import Decimal  # We're using Decimal.log10 instead of math.log10 because it allows us to use larger values of k

def prob_choose_prime(k: int) -> float:
  less_digits = Decimal(10 ** (k - 1) - 1)
  # We are calculating with_digits this way so we don't have to exponentiate
  # twice. Instead we multiply those with digits less than k by 10 and add 9
  # since 9 is the max value a digit can have. This results in the same
  # value as 10 ** k - 1, but with easier computations.
  with_digits = less_digits * 10 + 9
  max_nums = with_digits - less_digits

  total_primes = with_digits / with_digits.log10()
  lower_primes = (less_digits / less_digits.log10()) if less_digits > 0 else 0

  return float((total_primes - lower_primes) / max_nums)

# %%
prob_choose_prime(314)
# Out:
# 0.0031835828421164494
