# %% [markdown]
# <a href="https://colab.research.google.com/github/TheMikeste1/cse380-notebooks/blob/master/11_3_About_The_Petersen_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About The Petersen Graph
# ## Class Directed Learning
# ### Due: Tuesday, 16 March 2021, 11:59 pm

# %% [markdown]
# ## TODO Explore and Wonder

# %% [markdown]
# The Petersen graph is described as the complement of the line graph of $K_5$.
#
# Draw each step of this construction using any graph-drawing tools in your toolbox.
#
# Teach one another how to use the tools you each have.

# %% [markdown]
# See https://lucid.app/lucidchart/invitations/accept/7cae714d-0da4-4075-82c6-145a6f37613b
